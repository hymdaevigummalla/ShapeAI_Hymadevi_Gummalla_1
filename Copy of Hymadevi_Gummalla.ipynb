# %%
from keras.datasets import mnist
 
data = mnist.load_data()

# %%
((X_train, y_train), (X_test, y_test)) = data

# %%
X_train = X_train.reshape((X_train.shape[0], 28*28)).astype('float32')
X_test = X_test.reshape((X_test.shape[0], 28*28)).astype('float32')

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
from keras.utils import np_utils
 
print(y_test.shape)
 
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
 
num_classes = y_test.shape[1]
print(y_test.shape)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential ()
model.add(Dense(32, input_dim = 28*28, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 32)                25120
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                650
# =================================================================
# Total params: 27,882
# Trainable params: 27,882
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train,epochs=10, batch_size=100)
# Out:
# Epoch 1/10
# 600/600 [==============================] - 2s 2ms/step - loss: 0.7797 - accuracy: 0.7714
# Epoch 2/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2020 - accuracy: 0.9409
# Epoch 3/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1540 - accuracy: 0.9539
# Epoch 4/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1326 - accuracy: 0.9602
# Epoch 5/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1127 - accuracy: 0.9660
# Epoch 6/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1039 - accuracy: 0.9693
# Epoch 7/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0878 - accuracy: 0.9731
# Epoch 8/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0801 - accuracy: 0.9748
# Epoch 9/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0731 - accuracy: 0.9775
# Epoch 10/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0652 - accuracy: 0.9805

# %%
scores = model.evaluate(X_test, y_test)
print(scores)
# Out:
# 313/313 [==============================] - 0s 921us/step - loss: 0.1049 - accuracy: 0.9688
# [0.10485605150461197, 0.9688000082969666]
